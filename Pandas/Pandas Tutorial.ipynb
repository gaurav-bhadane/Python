# %%
import numpy as np
import pandas as pd

# %%
dict1= {
    "Name": ["Nitin","Gaurav","Ritik","Himanshu","Rohit"],
    "Marks": [45,95,98,91,52],
    "City":["Delhi","Nandurbar","Dhule","Jalgaon","Vavad"]
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#        Name  Marks       City
# 0     Nitin     45      Delhi
# 1    Gaurav     95  Nandurbar
# 2     Ritik     98      Dhule
# 3  Himanshu     91    Jalgaon
# 4     Rohit     52      Vavad

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_index_false.csv',index=False)

# %%
df.head(2)
# Out:
#      Name  Marks       City
# 0   Nitin     45      Delhi
# 1  Gaurav     95  Nandurbar

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Name  Marks       City
# 0     Nitin     45      Delhi
# 1    Gaurav     95  Nandurbar
# 2     Ritik     98      Dhule
# 3  Himanshu     91    Jalgaon
# 4     Rohit     52      Vavad>

# %%
df.describe()
# Out:
#            Marks
# count   5.000000
# mean   76.200000
# std    25.528416
# min    45.000000
# 25%    52.000000
# 50%    91.000000
# 75%    95.000000
# max    98.000000

# %%
gau = pd.read_csv('gaurav.csv')

# %%
gau
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 Train Name  Speed Destination
# 0             0             0           0   Shatabdi    145      Nashik
# 1             1             1           1   Navjivan    120       Surat
# 2             2             2           2    Duranto    160      Mumbai
# 3             3             3           3   Rajdhani    140       Delhi

# %%
gau["Speed"]
# Out:
# 0    145
# 1    120
# 2    160
# 3    140
# Name: Speed, dtype: int64

# %%
gau["Speed"][2]=160
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_41492\233775433.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gau["Speed"][2]=160

# %%
gau
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 Train Name  Speed Destination
# 0             0             0           0   Shatabdi    145      Nashik
# 1             1             1           1   Navjivan    120       Surat
# 2             2             2           2    Duranto    160      Mumbai
# 3             3             3           3   Rajdhani    140       Delhi

# %%
gau.to_csv('gaurav.csv')

# %%
gau
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 Train Name  Speed Destination
# 0             0             0           0   Shatabdi    145      Nashik
# 1             1             1           1   Navjivan    120       Surat
# 2             2             2           2    Duranto    160      Mumbai
# 3             3             3           3   Rajdhani    140       Delhi

# %%
gau.index = ['first','second','third','fourth']

# %%
gau
# Out:
#         Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 Train Name  Speed Destination
# first              0             0           0   Shatabdi    145      Nashik
# second             1             1           1   Navjivan    120       Surat
# third              2             2           2    Duranto    160      Mumbai
# fourth             3             3           3   Rajdhani    140       Delhi

# %%
gau.index = ['I','II','III','IV']

# %%
gau
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 Train Name  Speed Destination
# I               0             0           0   Shatabdi    145      Nashik
# II              1             1           1   Navjivan    120       Surat
# III             2             2           2    Duranto    160      Mumbai
# IV              3             3           3   Rajdhani    140       Delhi

# %%
ser=pd.Series(np.random.rand(30))

# %%
ser
# Out:
# 0     0.573432
# 1     0.230933
# 2     0.783860
# 3     0.250292
# 4     0.670339
# 5     0.913794
# 6     0.653507
# 7     0.411629
# 8     0.712121
# 9     0.215832
# 10    0.114804
# 11    0.355383
# 12    0.553655
# 13    0.674748
# 14    0.078893
# 15    0.393400
# 16    0.628854
# 17    0.699220
# 18    0.694427
# 19    0.892647
# 20    0.019093
# 21    0.768674
# 22    0.188657
# 23    0.554883
# 24    0.275025
# 25    0.572070
# 26    0.518389
# 27    0.902955
# 28    0.990128
# 29    0.010392
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf=pd.DataFrame(np.random.rand(334,4),index=np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3
# 0    0.935705  0.013477  0.472785  0.840523
# 1    0.746443  0.864281  0.880709  0.573353
# 2    0.637948  0.141532  0.021648  0.579615
# 3    0.485754  0.718373  0.052573  0.080703
# 4    0.900721  0.629038  0.183232  0.672842
# ..        ...       ...       ...       ...
# 329  0.878929  0.310724  0.192479  0.700224
# 330  0.009566  0.472599  0.822795  0.062625
# 331  0.135737  0.950856  0.797091  0.687775
# 332  0.076486  0.469679  0.649508  0.476464
# 333  0.537776  0.395899  0.387674  0.157710
#
# [334 rows x 4 columns]

# %%
newdf.head(5)
# Out:
#           0         1         2         3
# 0  0.935705  0.013477  0.472785  0.840523
# 1  0.746443  0.864281  0.880709  0.573353
# 2  0.637948  0.141532  0.021648  0.579615
# 3  0.485754  0.718373  0.052573  0.080703
# 4  0.900721  0.629038  0.183232  0.672842

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3
# count  334.000000  334.000000  334.000000  334.000000
# mean     0.504310    0.478044    0.537466    0.490006
# std      0.295695    0.291871    0.284305    0.296184
# min      0.001905    0.002244    0.012648    0.000015
# 25%      0.242960    0.232673    0.307110    0.223276
# 50%      0.532734    0.465321    0.560701    0.479995
# 75%      0.768924    0.720930    0.779840    0.751693
# max      0.993347    0.996862    0.997733    0.995905

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# dtype: object

# %%
newdf[0][0]="Gaurav"

# %%
newdf.head(5)
# Out:
#           0         1         2         3
# 0    Gaurav  0.013477  0.472785  0.840523
# 1  0.746443  0.864281  0.880709  0.573353
# 2  0.637948  0.141532  0.021648  0.579615
# 3  0.485754  0.718373  0.052573  0.080703
# 4  0.900721  0.629038  0.183232  0.672842

# %%
newdf.dtypes
# Out:
# 0     object
# 1    float64
# 2    float64
# 3    float64
# dtype: object

# %%
arr=newdf.to_numpy()

# %%
newdf[0][0]=0.256

# %%
newdf
# Out:
#             0         1         2         3
# 0       0.256  0.013477  0.472785  0.840523
# 1    0.746443  0.864281  0.880709  0.573353
# 2    0.637948  0.141532  0.021648  0.579615
# 3    0.485754  0.718373  0.052573  0.080703
# 4    0.900721  0.629038  0.183232  0.672842
# ..        ...       ...       ...       ...
# 329  0.878929  0.310724  0.192479  0.700224
# 330  0.009566  0.472599  0.822795  0.062625
# 331  0.135737  0.950856  0.797091  0.687775
# 332  0.076486  0.469679  0.649508  0.476464
# 333  0.537776  0.395899  0.387674  0.157710
#
# [334 rows x 4 columns]

# %%
arr
# Out:
# array([['Gaurav', 0.01347667640928929, 0.47278480332158235,
#         0.840522759352287],
#        [0.7464426332251909, 0.864281171938218, 0.8807091002176471,
#         0.5733528809637288],
#        [0.637948293025678, 0.1415323087454683, 0.021648459019787625,
#         0.5796146143417223],
#        ...,
#        [0.1357368386225113, 0.9508559748143952, 0.7970912847384077,
#         0.6877749497045113],
#        [0.07648649476294822, 0.4696790063653923, 0.6495081230640838,
#         0.47646390055895826],
#        [0.5377760118392797, 0.39589917723481405, 0.387673514760272,
#         0.15771014648101112]], dtype=object)

# %%
newdf
# Out:
#             0         1         2         3
# 0       0.256  0.013477  0.472785  0.840523
# 1    0.746443  0.864281  0.880709  0.573353
# 2    0.637948  0.141532  0.021648  0.579615
# 3    0.485754  0.718373  0.052573  0.080703
# 4    0.900721  0.629038  0.183232  0.672842
# ..        ...       ...       ...       ...
# 329  0.878929  0.310724  0.192479  0.700224
# 330  0.009566  0.472599  0.822795  0.062625
# 331  0.135737  0.950856  0.797091  0.687775
# 332  0.076486  0.469679  0.649508  0.476464
# 333  0.537776  0.395899  0.387674  0.157710
#
# [334 rows x 4 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3
# 0     0.256  0.013477  0.472785  0.840523
# 1  0.746443  0.864281  0.880709  0.573353
# 2  0.637948  0.141532  0.021648  0.579615
# 3  0.485754  0.718373  0.052573  0.080703
# 4  0.900721  0.629038  0.183232  0.672842

# %%
newdf.sort_index(axis=0,ascending=False)
# Out:
#             0         1         2         3
# 333  0.537776  0.395899  0.387674  0.157710
# 332  0.076486  0.469679  0.649508  0.476464
# 331  0.135737  0.950856  0.797091  0.687775
# 330  0.009566  0.472599  0.822795  0.062625
# 329  0.878929  0.310724  0.192479  0.700224
# ..        ...       ...       ...       ...
# 4    0.900721  0.629038  0.183232  0.672842
# 3    0.485754  0.718373  0.052573  0.080703
# 2    0.637948  0.141532  0.021648  0.579615
# 1    0.746443  0.864281  0.880709  0.573353
# 0       0.256  0.013477  0.472785  0.840523
#
# [334 rows x 4 columns]

# %%
newdf.sort_index(axis=1,ascending=False)
# Out:
#             3         2         1         0
# 0    0.840523  0.472785  0.013477     0.256
# 1    0.573353  0.880709  0.864281  0.746443
# 2    0.579615  0.021648  0.141532  0.637948
# 3    0.080703  0.052573  0.718373  0.485754
# 4    0.672842  0.183232  0.629038  0.900721
# ..        ...       ...       ...       ...
# 329  0.700224  0.192479  0.310724  0.878929
# 330  0.062625  0.822795  0.472599  0.009566
# 331  0.687775  0.797091  0.950856  0.135737
# 332  0.476464  0.649508  0.469679  0.076486
# 333  0.157710  0.387674  0.395899  0.537776
#
# [334 rows x 4 columns]

# %%
newdf2 = newdf.copy()

# %%
newdf
# Out:
#             0         1         2         3
# 0       0.256  0.013477  0.472785  0.840523
# 1    0.746443  0.864281  0.880709  0.573353
# 2    0.637948  0.141532  0.021648  0.579615
# 3    0.485754  0.718373  0.052573  0.080703
# 4    0.900721  0.629038  0.183232  0.672842
# ..        ...       ...       ...       ...
# 329  0.878929  0.310724  0.192479  0.700224
# 330  0.009566  0.472599  0.822795  0.062625
# 331  0.135737  0.950856  0.797091  0.687775
# 332  0.076486  0.469679  0.649508  0.476464
# 333  0.537776  0.395899  0.387674  0.157710
#
# [334 rows x 4 columns]

# %%
newdf
# Out:
#             0         1         2         3
# 0       0.256  0.013477  0.472785  0.840523
# 1    0.746443  0.864281  0.880709  0.573353
# 2    0.637948  0.141532  0.021648  0.579615
# 3    0.485754  0.718373  0.052573  0.080703
# 4    0.900721  0.629038  0.183232  0.672842
# ..        ...       ...       ...       ...
# 329  0.878929  0.310724  0.192479  0.700224
# 330  0.009566  0.472599  0.822795  0.062625
# 331  0.135737  0.950856  0.797091  0.687775
# 332  0.076486  0.469679  0.649508  0.476464
# 333  0.537776  0.395899  0.387674  0.157710
#
# [334 rows x 4 columns]

# %%
newdf
# Out:
#             0         1         2         3
# 0       0.256  0.013477  0.472785  0.840523
# 1    0.746443  0.864281  0.880709  0.573353
# 2    0.637948  0.141532  0.021648  0.579615
# 3    0.485754  0.718373  0.052573  0.080703
# 4    0.900721  0.629038  0.183232  0.672842
# ..        ...       ...       ...       ...
# 329  0.878929  0.310724  0.192479  0.700224
# 330  0.009566  0.472599  0.822795  0.062625
# 331  0.135737  0.950856  0.797091  0.687775
# 332  0.076486  0.469679  0.649508  0.476464
# 333  0.537776  0.395899  0.387674  0.157710
#
# [334 rows x 4 columns]

# %%
newdf
# Out:
#             0         1         2         3
# 0       0.256  0.013477  0.472785  0.840523
# 1    0.746443  0.864281  0.880709  0.573353
# 2    0.637948  0.141532  0.021648  0.579615
# 3    0.485754  0.718373  0.052573  0.080703
# 4    0.900721  0.629038  0.183232  0.672842
# ..        ...       ...       ...       ...
# 329  0.878929  0.310724  0.192479  0.700224
# 330  0.009566  0.472599  0.822795  0.062625
# 331  0.135737  0.950856  0.797091  0.687775
# 332  0.076486  0.469679  0.649508  0.476464
# 333  0.537776  0.395899  0.387674  0.157710
#
# [334 rows x 4 columns]

# %%
newdf2=newdf.copy()

# %%
newdf2
# Out:
#             0         1         2         3
# 0       0.256  0.013477  0.472785  0.840523
# 1    0.746443  0.864281  0.880709  0.573353
# 2    0.637948  0.141532  0.021648  0.579615
# 3    0.485754  0.718373  0.052573  0.080703
# 4    0.900721  0.629038  0.183232  0.672842
# ..        ...       ...       ...       ...
# 329  0.878929  0.310724  0.192479  0.700224
# 330  0.009566  0.472599  0.822795  0.062625
# 331  0.135737  0.950856  0.797091  0.687775
# 332  0.076486  0.469679  0.649508  0.476464
# 333  0.537776  0.395899  0.387674  0.157710
#
# [334 rows x 4 columns]

# %%
newdf.loc[0,0]=645

# %%
newdf.head()
# Out:
#           0         1         2         3
# 0       645  0.013477  0.472785  0.840523
# 1  0.746443  0.864281  0.880709  0.573353
# 2  0.637948  0.141532  0.021648  0.579615
# 3  0.485754  0.718373  0.052573  0.080703
# 4  0.900721  0.629038  0.183232  0.672842

# %%
newdf2
# Out:
#             0         1         2         3
# 0       0.256  0.013477  0.472785  0.840523
# 1    0.746443  0.864281  0.880709  0.573353
# 2    0.637948  0.141532  0.021648  0.579615
# 3    0.485754  0.718373  0.052573  0.080703
# 4    0.900721  0.629038  0.183232  0.672842
# ..        ...       ...       ...       ...
# 329  0.878929  0.310724  0.192479  0.700224
# 330  0.009566  0.472599  0.822795  0.062625
# 331  0.135737  0.950856  0.797091  0.687775
# 332  0.076486  0.469679  0.649508  0.476464
# 333  0.537776  0.395899  0.387674  0.157710
#
# [334 rows x 4 columns]

# %%
newdf.dtypes
# Out:
# 0     object
# 1    float64
# 2    float64
# 3    float64
# dtype: object

# %%
newdf.columns=list("ABCD")

# %%
newdf.head()
# Out:
#           A         B         C         D
# 0       645  0.013477  0.472785  0.840523
# 1  0.746443  0.864281  0.880709  0.573353
# 2  0.637948  0.141532  0.021648  0.579615
# 3  0.485754  0.718373  0.052573  0.080703
# 4  0.900721  0.629038  0.183232  0.672842

# %%
newdf.loc[0,"A"]=412

# %%
newdf.head()
# Out:
#           A         B         C         D
# 0       412  0.013477  0.472785  0.840523
# 1  0.746443  0.864281  0.880709  0.573353
# 2  0.637948  0.141532  0.021648  0.579615
# 3  0.485754  0.718373  0.052573  0.080703
# 4  0.900721  0.629038  0.183232  0.672842

# %%
newdf.loc[[1,2],["C","D"]]
# Out:
#           C         D
# 1  0.880709  0.573353
# 2  0.021648  0.579615

# %%
newdf.loc[:,["C","D"]]
# Out:
#             C         D
# 0    0.472785  0.840523
# 1    0.880709  0.573353
# 2    0.021648  0.579615
# 3    0.052573  0.080703
# 4    0.183232  0.672842
# ..        ...       ...
# 329  0.192479  0.700224
# 330  0.822795  0.062625
# 331  0.797091  0.687775
# 332  0.649508  0.476464
# 333  0.387674  0.157710
#
# [334 rows x 2 columns]

# %%
newdf.loc[[1,2],:]
# Out:
#           A         B         C         D
# 1  0.746443  0.864281  0.880709  0.573353
# 2  0.637948  0.141532  0.021648  0.579615

# %%
newdf.loc[(newdf["A"]<0.3) & (newdf["C"]>0.1)]
# Out:
#             A         B         C         D
# 21     0.2497  0.508993  0.883870  0.046635
# 22   0.013133  0.185432  0.202538  0.664708
# 31   0.233731  0.266869  0.610910  0.813506
# 33   0.261618  0.953718  0.396404  0.622077
# 37   0.262703  0.985282  0.712256  0.169743
# ..        ...       ...       ...       ...
# 327  0.008452  0.198470  0.621143  0.306045
# 328  0.125129  0.939840  0.117582  0.947656
# 330  0.009566  0.472599  0.822795  0.062625
# 331  0.135737  0.950856  0.797091  0.687775
# 332  0.076486  0.469679  0.649508  0.476464
#
# [95 rows x 4 columns]

# %%
newdf.head()
# Out:
#           A         B         C         D
# 0       412  0.013477  0.472785  0.840523
# 1  0.746443  0.864281  0.880709  0.573353
# 2  0.637948  0.141532  0.021648  0.579615
# 3  0.485754  0.718373  0.052573  0.080703
# 4  0.900721  0.629038  0.183232  0.672842

# %%
newdf.iloc[1,3]
# Out:
# 0.5733528809637288

# %%
newdf.iloc[[0,1],[1,2]]
# Out:
#           B         C
# 0  0.013477  0.472785
# 1  0.864281  0.880709

# %%
newdf.drop([0])
# Out:
#             A         B         C         D
# 1    0.746443  0.864281  0.880709  0.573353
# 2    0.637948  0.141532  0.021648  0.579615
# 3    0.485754  0.718373  0.052573  0.080703
# 4    0.900721  0.629038  0.183232  0.672842
# 5     0.74639  0.625875  0.715349  0.532801
# ..        ...       ...       ...       ...
# 329  0.878929  0.310724  0.192479  0.700224
# 330  0.009566  0.472599  0.822795  0.062625
# 331  0.135737  0.950856  0.797091  0.687775
# 332  0.076486  0.469679  0.649508  0.476464
# 333  0.537776  0.395899  0.387674  0.157710
#
# [333 rows x 4 columns]

# %%
newdf["B"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# Name: B, Length: 334, dtype: bool

# %% [markdown]
# *** Create DataFrame whuih contains only integers with 3 rows and 2 columns and run following dataframe method on them
# df.decribe()
# df.mean()
# df.corr()
# df.count()
# df.max()
# df.min()
# df.median()
# df.std() ***

# %%
data=pd.DataFrame(np.random.randint(1,100,size=(3,2)))

# %%
data
# Out:
#     0   1
# 0  28  99
# 1  32  48
# 2  73  43

# %%
data.columns=list("AB")

# %%
data.rows=list("ab")

# %%
data
# Out:
#     A   B
# 0  28  99
# 1  32  48
# 2  73  43

# %%
data.describe()
# Out:
#                A          B
# count   3.000000   3.000000
# mean   44.333333  63.333333
# std    24.906492  30.989245
# min    28.000000  43.000000
# 25%    30.000000  45.500000
# 50%    32.000000  48.000000
# 75%    52.500000  73.500000
# max    73.000000  99.000000

# %%
data.mean()
# Out:
# A    44.333333
# B    63.333333
# dtype: float64

# %%
data.corr()
# Out:
#           A         B
# A  1.000000 -0.632477
# B -0.632477  1.000000

# %%
data.count()
# Out:
# A    3
# B    3
# dtype: int64

# %%
data.max()
# Out:
# A    73
# B    99
# dtype: int32

# %%
data.min()
# Out:
# A    28
# B    43
# dtype: int32

# %%
data.median()
# Out:
# A    32.0
# B    48.0
# dtype: float64

# %%
data.std()
# Out:
# A    24.906492
# B    30.989245
# dtype: float64
